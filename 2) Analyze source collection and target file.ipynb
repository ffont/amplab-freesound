# %% [markdown]
# # 2) Analyze source collection and target file
#
# This notebook includes the code to analyze the collection of sounds compiled in the previous notebook and that will be later used as the source collection in our audio mosaicing code. The notebook also contains the code to analyze the target audio file that will be later reconstructed using sound chunks from the source collection.
#
# The audio analysis carried out in this notebook uses the Pythonn bindings of the Essentia library which was introduced in the first session of AMPLAB. Please make sure you checked the [Essentia Python tutorial](https://essentia.upf.edu/documentation/essentia_python_tutorial.html) to get familiarized with using Essentia in Python. Also useful is to always have a browser tab opened with Essentia's [Algorithms Reference](https://essentia.upf.edu/documentation/algorithms_reference.html) documentation page.

# %%
import pandas as pd
import essentia
import essentia.standard as estd
import matplotlib.pyplot as plt
from IPython.display import display, Audio

# %%
# Define here our sound analysis function
# NOTE: remember that if you update this function and want to run a new analysis you'll need to re-run both 
# this cell and the cells below that carry out the audio analysis and that call the analysis function. 
# After analyzing the source collection or the target file, make sure to correct descriptors have been 
# extracted by checking the DataFrame contents. DataFrame contents can be printed on screen as a table 
# using 'display(data_frame_object)'

def analyze_sound(audio_path, frame_size=None, audio_id=None):
    """Analyze the audio file given in 'sound_path'.
    Use the parameter 'frame_size' to set the size of the chunks in which the audio will 
    be split for analysis. If no frame_size is given, the whole audio will be analyzed as 
    a single frame.
    Use the 'audio_id' parameter to pass a custom identifier for the audio that will be 
    included in the analysis results. This can be useful to later identify to which file an analysis belongs.
    """
    analysis_output = []  # Here we'll store the analysis results for each chunk (frame) of the audio file
    
    # Load audio file
    loader = estd.MonoLoader(filename=audio_path)
    audio = loader()
    
    # Some processing of frame_size parameter to avoid later problems
    if frame_size is None:
        frame_size = len(audio)  # If no frame_size is given use no frames (analyze all audio at once)
    if frame_size % 2 != 0:
        frame_size = frame_size + 1 # Make frame size even
    
    # Calculate the start and end samples for each equally-spaced audio frame
    frame_start_samples = range(0, len(audio), frame_size)
    frame_start_end_samples = zip(frame_start_samples[:-1], frame_start_samples[1:])
    
    # Iterate over audio frames and analyze each one
    for count, (fstart, fend) in enumerate(frame_start_end_samples):
        
        # Get corresponding audio chunk and initialize dictionary to sotre analysis results with some basic metadata
        frame = audio[fstart:fend]
        frame_output = {
            'freesound_id': audio_id,
            'id': '{0}_f{1}'.format(audio_id, count),
            'path': audio_path,
            'start_sample': fstart,
            'end_sample': fend,
        }
        
        # Extract loudness
        loudness_algo = estd.Loudness()
        loudness = loudness_algo(frame)
        frame_output['loudness'] = loudness / len(frame)  # Normnalize by length of frame

        # Extract MFCC coefficients
        w_algo = estd.Windowing(type = 'hann')
        spectrum_algo = estd.Spectrum()
        mfcc_algo = estd.MFCC()
        spec = spectrum_algo(w_algo(frame))
        _, mfcc_coeffs = mfcc_algo(spec)
        frame_output.update({'mfcc_{0}'.format(j): mfcc_coeffs[j] for j in range(0, len(mfcc_coeffs))})
        
        # Extract other features here and add to 'frame_output' dictionary
        # ...
        
        # Add frame analysis results to output
        analysis_output.append(frame_output)

    return analysis_output

# %% [markdown]
# ## Analyze source collection

# %%
DATAFRAME_FILENAME = 'dataframe.csv'  # DataFrame file of the sound source collection to analyze
DATAFRAME_SOURCE_FILENAME = 'dataframe_source.csv'  # DataFrame file where to store the results of our analysis

# Load the DataFrame of the sound source collection created in previous notebook and analyze all sound files in it
df = pd.read_csv(open(DATAFRAME_FILENAME), index_col=0)
analyses = []
for i in range(0, len(df)):
    sound = df.iloc[i]  # Get DataFrame sound at position 'i'
    print('Analyzing sound with id {0} [{1}/{2}]'.format(sound['freesound_id'], i + 1, len(df)))
    analysis_output = analyze_sound(sound['path'], frame_size=8820, audio_id=sound['freesound_id'])  # Split audio in chunks of 200ms (44100/5 samples)
    analyses += analysis_output

# Store analysis results in a new Pandas DataFrame and save it
df_source = pd.DataFrame(analyses)
df_source.to_csv(DATAFRAME_SOURCE_FILENAME)
print('Saved source DataFrame with {0} entries! {1}'.format(len(df_source), DATAFRAME_SOURCE_FILENAME))

display(df_source)  # Show DataFrane contents
df_source.describe()  # Show some statistics of numerical fields in the DataFrame
# Out:
# Analyzing sound with id 337101 [1/60]
# Analyzing sound with id 327666 [2/60]
# Analyzing sound with id 413758 [3/60]
# Analyzing sound with id 163459 [4/60]
# Analyzing sound with id 456943 [5/60]
# Analyzing sound with id 418106 [6/60]
# Analyzing sound with id 420448 [7/60]
# Analyzing sound with id 236016 [8/60]
# Analyzing sound with id 115536 [9/60]
# Analyzing sound with id 160093 [10/60]
# Analyzing sound with id 180977 [11/60]
# Analyzing sound with id 157322 [12/60]
# Analyzing sound with id 118964 [13/60]
# Analyzing sound with id 386766 [14/60]
# Analyzing sound with id 425904 [15/60]
# Analyzing sound with id 199261 [16/60]
# Analyzing sound with id 277058 [17/60]
# Analyzing sound with id 446593 [18/60]
# Analyzing sound with id 408810 [19/60]
# Analyzing sound with id 424593 [20/60]
# Analyzing sound with id 124100 [21/60]
# Analyzing sound with id 57040 [22/60]
# Analyzing sound with id 260468 [23/60]
# Analyzing sound with id 183115 [24/60]
# Analyzing sound with id 338747 [25/60]
# Analyzing sound with id 424372 [26/60]
# Analyzing sound with id 264173 [27/60]
# Analyzing sound with id 31061 [28/60]
# Analyzing sound with id 207919 [29/60]
# Analyzing sound with id 249971 [30/60]
# Analyzing sound with id 193978 [31/60]
# Analyzing sound with id 139500 [32/60]
# Analyzing sound with id 111163 [33/60]
# Analyzing sound with id 345679 [34/60]
# Analyzing sound with id 65688 [35/60]
# Analyzing sound with id 329924 [36/60]
# Analyzing sound with id 63240 [37/60]
# Analyzing sound with id 396226 [38/60]
# Analyzing sound with id 399329 [39/60]
# Analyzing sound with id 347121 [40/60]
# Analyzing sound with id 315688 [41/60]
# Analyzing sound with id 75511 [42/60]
# Analyzing sound with id 33753 [43/60]
# Analyzing sound with id 272029 [44/60]
# Analyzing sound with id 87649 [45/60]
# Analyzing sound with id 432875 [46/60]
# Analyzing sound with id 88159 [47/60]
# Analyzing sound with id 251683 [48/60]
# Analyzing sound with id 417506 [49/60]
# Analyzing sound with id 88402 [50/60]
# Analyzing sound with id 150505 [51/60]
# Analyzing sound with id 166161 [52/60]
# Analyzing sound with id 180343 [53/60]
# Analyzing sound with id 166357 [54/60]
# Analyzing sound with id 112582 [55/60]
# Analyzing sound with id 181881 [56/60]
# Analyzing sound with id 215363 [57/60]
# Analyzing sound with id 87697 [58/60]
# Analyzing sound with id 256359 [59/60]
# Analyzing sound with id 254275 [60/60]
# Saved source DataFrame with 980 entries! dataframe_source.csv
#      end_sample  freesound_id          id  loudness       mfcc_0      mfcc_1  \
# 0          8820        337101   337101_f0  0.021004  -563.784241  150.048553
# 1         17640        337101   337101_f1  0.017605  -626.487732  154.187714
# 2         26460        337101   337101_f2  0.015988  -617.014954  155.761932
# 3         35280        337101   337101_f3  0.014047  -613.387085  139.480225
# 4         44100        337101   337101_f4  0.014454  -602.648926  152.130661
# 5         52920        337101   337101_f5  0.000738  -898.818665  193.091492
# 6         61740        337101   337101_f6  0.000148  -942.684692  153.391083
# 7         70560        337101   337101_f7  0.000118  -961.981140  152.101288
# 8         79380        337101   337101_f8  0.000097  -969.338379  144.877106
# 9         88200        337101   337101_f9  0.000084  -992.662781  143.269470
# 10        97020        337101  337101_f10  0.000100  -988.626831  149.384735
# 11       105840        337101  337101_f11  0.000028 -1044.435181  102.341316
# 12       114660        337101  337101_f12  0.000025 -1058.835327   89.371010
# 13       123480        337101  337101_f13  0.000013 -1069.657349   76.369728
# 14       132300        337101  337101_f14  0.000086  -963.182007  147.086548
# 15       141120        337101  337101_f15  0.000092  -983.437256  139.527008
# 16       149940        337101  337101_f16  0.000078 -1013.683044  124.799416
# 17       158760        337101  337101_f17  0.000100  -989.735718  137.315552
# 18       167580        337101  337101_f18  0.000045 -1004.726746  127.631905
# 19       176400        337101  337101_f19  0.000011 -1063.445679   81.285500
# 20       185220        337101  337101_f20  0.000007 -1076.714111   68.050606
# 21       194040        337101  337101_f21  0.000230 -1002.004456  132.459717
# 22       202860        337101  337101_f22  0.000403  -906.878296  169.635590
# 23       211680        337101  337101_f23  0.000254  -906.171448  145.509308
# 24       220500        337101  337101_f24  0.000445  -923.145569  162.599152
# 25       229320        337101  337101_f25  0.000154  -957.045410  134.039062
# 26       238140        337101  337101_f26  0.000137  -930.500061  135.313904
# 27       246960        337101  337101_f27  0.000030 -1016.696289  113.772072
# 28       255780        337101  337101_f28  0.000012 -1057.270874   83.982460
# 29       264600        337101  337101_f29  0.000020 -1047.052002   95.184425
# ..          ...           ...         ...       ...          ...         ...
# 950       17640        166161   166161_f1  0.000020 -1038.328369   61.801765
# 951       26460        166161   166161_f2  0.000008 -1095.928345   50.343639
# 952       35280        166161   166161_f3  0.000001 -1134.922852    4.867931
# 953        8820        180343   180343_f0  0.004001  -698.744141   16.969170
# 954       17640        180343   180343_f1  0.010683  -618.962402   46.645779
# 955       26460        180343   180343_f2  0.010687  -649.695312   51.460869
# 956        8820        166357   166357_f0  0.002429  -748.921875  113.004639
# 957       17640        166357   166357_f1  0.004218  -706.003113  125.133224
# 958       26460        166357   166357_f2  0.004836  -699.559570  135.302353
# 959       35280        166357   166357_f3  0.001253  -812.119812  162.208466
# 973  files/256359_4062622-hq.ogg             0
# 974  files/256359_4062622-hq.ogg          8820
# 975  files/256359_4062622-hq.ogg         17640
# 976  files/256359_4062622-hq.ogg         26460
# 977  files/254275_4062622-hq.ogg             0
# 978  files/254275_4062622-hq.ogg          8820
# 979  files/254275_4062622-hq.ogg         17640
#
# [980 rows x 19 columns]
#          end_sample   freesound_id    loudness       mfcc_0      mfcc_1  \
# count  9.800000e+02     980.000000  980.000000   980.000000  980.000000
# mean   3.820950e+05  298303.684694    0.002511  -921.770157  114.089339
# std    3.316632e+05  123108.691709    0.004349   156.743607   68.191187
# min    8.820000e+03   31061.000000    0.000000 -1138.420044 -114.325630
# 25%    8.820000e+04  180977.000000    0.000025 -1051.900909   69.471735
# 50%    2.998800e+05  337101.000000    0.000392  -938.275482  117.092010
# 75%    6.174000e+05  424593.000000    0.003098  -814.039551  166.768822
# max    1.278900e+06  456943.000000    0.029948  -436.876892  275.389221
#
#           mfcc_10     mfcc_11     mfcc_12      mfcc_2      mfcc_3      mfcc_4  \
# count  980.000000  980.000000  980.000000  980.000000  980.000000  980.000000
# mean     2.483363    2.484282    0.340943   -4.885410  -16.425068  -16.796357
# std     12.185432   10.061072   10.117917   51.213286   37.832635   29.943550
# min    -33.786526  -30.786617  -44.275017 -184.286194 -122.173500 -114.456406
# 25%     -4.046921   -3.913151   -5.034113  -37.122151  -45.646660  -33.411427
# 50%      2.018031    2.091892    0.312096   -0.000061  -10.478493   -9.924194
# 75%      9.670317    8.414176    5.623934   25.930061    9.743969    3.600498
# max     42.838924   30.827501   39.152111  122.852234  175.543091   64.721619
#
#            mfcc_5      mfcc_6      mfcc_7      mfcc_8      mfcc_9  \
# count  980.000000  980.000000  980.000000  980.000000  980.000000
# mean    -6.812070  -10.185819   -3.076972   -0.357179    1.686236
# std     20.023574   23.700366   16.410624   13.557837   12.310749
# min    -76.957794  -88.464355  -60.955299  -57.012321  -47.844254
# 25%    -16.857454  -26.425261  -10.469358   -7.050398   -4.608997
# 50%     -2.182041   -1.997700   -0.000053    1.527859    2.566395
# 75%      6.816469    7.181068    7.011410    8.350634    8.132702
# max     54.962067   39.150261   38.817883   47.706020   51.229511
#
#        start_sample
# count  9.800000e+02
# mean   3.732750e+05
# std    3.316632e+05
# min    0.000000e+00
# 25%    7.938000e+04
# 50%    2.910600e+05
# 75%    6.085800e+05
# max    1.270080e+06

# %% [markdown]
# ## Analyze the target sound file

# %%
TARGET_SOUND_PATH = '262350__stereo-surgeon__grinder-drum-loop.wav'  # Filename of the target audio we'll reconstruct
DATAFRAME_TARGET_FILE_FILENAME = 'dataframe_target.csv'  # DataFrame file where to store the analysis results of the target audio

# Analyze the target audio file and store results in a new DataFrame
print('Analyzing target sound {0}'.format(TARGET_SOUND_PATH))
target_analysis = analyze_sound(TARGET_SOUND_PATH, frame_size=8820)  # Also split audio in chunks of 200ms (44100/5 samples) 
df_target = pd.DataFrame(target_analysis)
df_target.to_csv(DATAFRAME_TARGET_FILE_FILENAME)
print('Saved target dataframe with {0} entries! {1}'.format(len(df_target), DATAFRAME_TARGET_FILE_FILENAME))

# Plot target audio file waveform and show ticks at the start samples of the chunks
plt.figure(figsize=(15,5))
audio = estd.MonoLoader(filename=TARGET_SOUND_PATH)()
plt.plot(audio)
plt.vlines(df_target['start_sample'].values, -1, 1, color='red')
plt.axis([0, min(len(audio), 44100 * 4), -1, 1])
plt.title('Target audio file (first 4 seconds)')
plt.show()

display(df_target)  # Show data frame contents
df_target.describe()  # Show statistics of numerical fields in data frame
# Out:
# Analyzing target sound 262350__stereo-surgeon__grinder-drum-loop.wav
# Saved target dataframe with 147 entries! dataframe_target.csv
#      end_sample freesound_id         id  loudness       mfcc_0      mfcc_1  \
# 0          8820         None    None_f0  0.016481  -912.375793  227.141754
# 1         17640         None    None_f1  0.007869  -687.080627  189.494156
# 2         26460         None    None_f2  0.015003  -629.191772  159.515259
# 3         35280         None    None_f3  0.011783  -776.993652  213.831024
# 4         44100         None    None_f4  0.013545  -616.678162  149.881943
# 5         52920         None    None_f5  0.010096 -1022.262939  145.248962
# 6         61740         None    None_f6  0.010430  -726.911133  216.713608
# 7         70560         None    None_f7  0.016835  -817.346191  192.341156
# 8         79380         None    None_f8  0.009343  -684.241272  193.516479
# 9         88200         None    None_f9  0.015771  -666.343689  167.627625
# 10        97020         None   None_f10  0.007205  -817.046814  171.940369
# 11       105840         None   None_f11  0.013650  -602.948364  149.337265
# 12       114660         None   None_f12  0.013182  -772.033875  229.604462
# 13       123480         None   None_f13  0.012071  -698.995178  187.839188
# 14       132300         None   None_f14  0.013176  -971.624207  191.998962
# 15       141120         None   None_f15  0.007600  -680.311523  192.830078
# 16       149940         None   None_f16  0.016554  -724.732727  180.763153
# 17       158760         None   None_f17  0.011576  -755.893555  203.531921
# 18       167580         None   None_f18  0.014387  -599.645447  152.394272
# 19       176400         None   None_f19  0.007405 -1050.966919  113.045753
# 20       185220         None   None_f20  0.012502  -672.560791  165.750763
# 21       194040         None   None_f21  0.015810  -800.314026  214.637909
# 22       202860         None   None_f22  0.008192  -666.369019  175.931183
# 23       211680         None   None_f23  0.016053  -814.986816  205.929565
# 24       220500         None   None_f24  0.007306  -719.011169  181.083954
# 25       229320         None   None_f25  0.014562  -607.365540  155.449203
# 26       238140         None   None_f26  0.011450  -768.071899  208.987579
# 27       246960         None   None_f27  0.013769  -632.628357  160.338333
# 28       255780         None   None_f28  0.010940 -1007.850037  159.784088
# 29       264600         None   None_f29  0.007635  -690.553955  182.330536
# ..          ...          ...        ...       ...          ...         ...
# 117     1040760         None  None_f117  0.011661  -666.777039  143.346588
# 118     1049580         None  None_f118  0.012137  -678.586609  116.343170
# 119     1058400         None  None_f119  0.006622  -698.647522  144.136017
# 120     1067220         None  None_f120  0.015376  -915.147339  226.008972
# 121     1076040         None  None_f121  0.007874  -666.470215  125.332062
# 122     1084860         None  None_f122  0.012847  -643.336182  159.517517
# 123     1093680         None  None_f123  0.009235  -779.646301  149.451080
# 124     1102500         None  None_f124  0.011517  -635.575684  145.636353
# 142  21.011106  29.327246  20.253391   8.834185   8.769249
# 143  -2.666828  11.815575  11.926109  14.266991  19.031960
# 144 -13.411224  -4.439648  -8.550350  -3.676701   5.111139
# 145  -0.017265   0.057529   0.088509   0.052048  -0.024078
# 146 -25.314579 -19.073072  -9.997257  -0.690147  -0.433628
#
#                                               path  start_sample
# 0    262350__stereo-surgeon__grinder-drum-loop.wav             0
# 1    262350__stereo-surgeon__grinder-drum-loop.wav          8820
# 2    262350__stereo-surgeon__grinder-drum-loop.wav         17640
# 3    262350__stereo-surgeon__grinder-drum-loop.wav         26460
# 4    262350__stereo-surgeon__grinder-drum-loop.wav         35280
# 5    262350__stereo-surgeon__grinder-drum-loop.wav         44100
# 6    262350__stereo-surgeon__grinder-drum-loop.wav         52920
# 7    262350__stereo-surgeon__grinder-drum-loop.wav         61740
# 8    262350__stereo-surgeon__grinder-drum-loop.wav         70560
# 9    262350__stereo-surgeon__grinder-drum-loop.wav         79380
# 10   262350__stereo-surgeon__grinder-drum-loop.wav         88200
# 11   262350__stereo-surgeon__grinder-drum-loop.wav         97020
# 12   262350__stereo-surgeon__grinder-drum-loop.wav        105840
# 13   262350__stereo-surgeon__grinder-drum-loop.wav        114660
# 14   262350__stereo-surgeon__grinder-drum-loop.wav        123480
# 15   262350__stereo-surgeon__grinder-drum-loop.wav        132300
# 16   262350__stereo-surgeon__grinder-drum-loop.wav        141120
# 17   262350__stereo-surgeon__grinder-drum-loop.wav        149940
# 18   262350__stereo-surgeon__grinder-drum-loop.wav        158760
# 19   262350__stereo-surgeon__grinder-drum-loop.wav        167580
# 20   262350__stereo-surgeon__grinder-drum-loop.wav        176400
# 21   262350__stereo-surgeon__grinder-drum-loop.wav        185220
# 22   262350__stereo-surgeon__grinder-drum-loop.wav        194040
# 23   262350__stereo-surgeon__grinder-drum-loop.wav        202860
# 24   262350__stereo-surgeon__grinder-drum-loop.wav        211680
# 25   262350__stereo-surgeon__grinder-drum-loop.wav        220500
# 26   262350__stereo-surgeon__grinder-drum-loop.wav        229320
# 27   262350__stereo-surgeon__grinder-drum-loop.wav        238140
# 28   262350__stereo-surgeon__grinder-drum-loop.wav        246960
# 29   262350__stereo-surgeon__grinder-drum-loop.wav        255780
# ..                                             ...           ...
# 117  262350__stereo-surgeon__grinder-drum-loop.wav       1031940
# 118  262350__stereo-surgeon__grinder-drum-loop.wav       1040760
# 119  262350__stereo-surgeon__grinder-drum-loop.wav       1049580
# 120  262350__stereo-surgeon__grinder-drum-loop.wav       1058400
# 121  262350__stereo-surgeon__grinder-drum-loop.wav       1067220
# 122  262350__stereo-surgeon__grinder-drum-loop.wav       1076040
# 123  262350__stereo-surgeon__grinder-drum-loop.wav       1084860
# 124  262350__stereo-surgeon__grinder-drum-loop.wav       1093680
# 125  262350__stereo-surgeon__grinder-drum-loop.wav       1102500
# 126  262350__stereo-surgeon__grinder-drum-loop.wav       1111320
# 127  262350__stereo-surgeon__grinder-drum-loop.wav       1120140
# 128  262350__stereo-surgeon__grinder-drum-loop.wav       1128960
# 129  262350__stereo-surgeon__grinder-drum-loop.wav       1137780
# 130  262350__stereo-surgeon__grinder-drum-loop.wav       1146600
# 131  262350__stereo-surgeon__grinder-drum-loop.wav       1155420
# 132  262350__stereo-surgeon__grinder-drum-loop.wav       1164240
# 133  262350__stereo-surgeon__grinder-drum-loop.wav       1173060
# 134  262350__stereo-surgeon__grinder-drum-loop.wav       1181880
# 135  262350__stereo-surgeon__grinder-drum-loop.wav       1190700
# 136  262350__stereo-surgeon__grinder-drum-loop.wav       1199520
# 137  262350__stereo-surgeon__grinder-drum-loop.wav       1208340
# 138  262350__stereo-surgeon__grinder-drum-loop.wav       1217160
# 139  262350__stereo-surgeon__grinder-drum-loop.wav       1225980
# 140  262350__stereo-surgeon__grinder-drum-loop.wav       1234800
# 141  262350__stereo-surgeon__grinder-drum-loop.wav       1243620
# 142  262350__stereo-surgeon__grinder-drum-loop.wav       1252440
# 143  262350__stereo-surgeon__grinder-drum-loop.wav       1261260
# 144  262350__stereo-surgeon__grinder-drum-loop.wav       1270080
# 145  262350__stereo-surgeon__grinder-drum-loop.wav       1278900
# 146  262350__stereo-surgeon__grinder-drum-loop.wav       1287720
#
# [147 rows x 19 columns]
#          end_sample    loudness       mfcc_0      mfcc_1     mfcc_10  \
# count  1.470000e+02  147.000000   147.000000  147.000000  147.000000
# mean   6.526800e+05    0.010611  -741.194765  151.750358   10.879126
# std    3.755498e+05    0.004316   126.279285   42.501587    8.223984
# min    8.820000e+03    0.000019 -1138.357300    0.054882  -18.434673
# 25%    3.307500e+05    0.007872  -784.819183  135.877167    4.930024
# 50%    6.526800e+05    0.011450  -693.971313  152.343063   11.091829
# 75%    9.746100e+05    0.013727  -654.883331  180.618301   16.730885
# max    1.296540e+06    0.018259  -599.645447  229.604462   30.213848
#
#           mfcc_11     mfcc_12      mfcc_2      mfcc_3      mfcc_4      mfcc_5  \
# count  147.000000  147.000000  147.000000  147.000000  147.000000  147.000000
# mean     4.619174   -2.294727    2.701394   26.691574   11.407145   17.868998
# std      6.903667    9.336212   50.847979   27.054610   18.514661   14.478411
# min    -16.944710  -20.037846 -132.812393  -74.098473  -54.044147  -35.840565
# 25%      0.930128  -10.618545  -26.889775   15.766788    7.366062   16.690987
# 50%      4.585035   -0.453133   -6.119999   38.201832   16.295853   22.102619
# 75%      8.093996    3.847141   24.397156   45.108627   23.303320   24.626335
# max     21.801502   21.726311  117.380859   60.481056   42.558659   41.835251
#
#            mfcc_6      mfcc_7      mfcc_8      mfcc_9  start_sample
# count  147.000000  147.000000  147.000000  147.000000  1.470000e+02
# mean     9.729604   10.229332   12.084202    4.876471  6.438600e+05
# std     14.584409    9.599035    8.878799   10.253712  3.755498e+05
# min    -40.845459  -34.908962  -27.015514  -21.575787  0.000000e+00
# 25%     -0.112516    6.278240    9.028919   -2.629093  3.219300e+05
# 50%     10.437927   11.692421   13.540495    6.690327  6.438600e+05
# 75%     21.132659   15.540685   17.974619   12.552691  9.657900e+05
# max     32.909794   28.128809   32.444920   25.270288  1.287720e+06
